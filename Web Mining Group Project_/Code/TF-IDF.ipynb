# %%
import pandas as pd
import nltk
from nltk import word_tokenize
from sklearn.metrics import pairwise_distances
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import normalize
import re
import string
# import spacy
from nltk.stem import WordNetLemmatizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Step 1 extract the data from the csv files
data_1 = pd.read_csv('Brooklyn_openreviews_10.csv')
data_2 = pd.read_csv('Brooklyn_reviews_closed_10.csv')
data_3 = pd.read_csv('Manhattan__openreviews_10.csv')
data_4 = pd.read_csv('Manhattan_reviews_closed_10.csv')

data_1 = data_1.values.flatten().astype('str')
data_2 = data_2.values.flatten().astype('str')
data_3 = data_3.values.flatten().astype('str')
data_4 = data_4.values.flatten().astype('str')

# %%
#Step 2 define the tokenize function and compute_tf_idf function
def tokenize(doc, lemmatized=True, stopword=True, punctuation=True):
    tokens = []
    tokens = word_tokenize(doc.lower())
    if stopword == False:
        stop_words = nltk.corpus.stopwords.words('english')
        tokens = [token for token in tokens
                  if token.strip() not in stop_words]
    if punctuation == False:
        tokens = [token for token in tokens
                  if token.strip() not in string.punctuation]
    if lemmatized == True:
        wordnet_lemmatizer = WordNetLemmatizer()
        tokens = [wordnet_lemmatizer.lemmatize(token) for token in tokens]
    return tokens

# %%
def compute_tfidf(docs, lemmatized=True, stopword=True, punctuation=False):
    docs_tokens = {idx:nltk.FreqDist(tokenize(doc, lemmatized, stopword, punctuation))for idx, doc in enumerate(docs)}
    dtm = pd.DataFrame.from_dict(docs_tokens, orient="index")
    dtm = dtm.fillna(0)
    dtm = dtm.sort_index(axis=0)
    vocabulary = dtm.columns.values
    tf = dtm.values
    doc_len = tf.sum(axis=1)
    tf = np.divide(tf.T, doc_len).T
    df = np.where(tf > 0, 1, 0)
    smoothed_idf = np.log(np.divide(len(docs) + 1, np.sum(df, axis=0) + 1)) + 1
    smoothed_tf_idf = tf * smoothed_idf
    return smoothed_tf_idf, smoothed_idf, vocabulary

# %%
def extract_top_5(tf_idf, vocabulary):
    return [list(vocabulary[np.argsort(row)][-1:-6:-1]) for row in tf_idf]

# %%
for i, data in enumerate([data_1, data_2, data_3, data_4]):
    tf_idf_data, _, vocab_data = compute_tfidf(data, True, False, False)
    print('The top_5 frequent words mentioned in each review in File {} are:'.format(i+1))
    print(extract_top_10(tf_idf_data, vocab_data))
# Out:
# The top_5 frequent words mentioned in each review in File 1 are:
# [['otis', 'fishy', 'speel', 'onto', 'accompaniment'], ['cous', 'since', 'also', 'otisbk.com/menu-hours', 'pick-up'], ['time', '5', 'area', 'first', 'decided'], ['squash', 'nervous', 'chanelle', 'fennel', 'outbreak'], ['meat', 'lot', 'commute', 'writing', 'exquisite'], ['definitely', 'crumble', 'legroom', 'mind-blowing', 'rave'], ['ear', 'curry', 'night', 'mussel', 'beef'], ['must', 'chef', 'long', 'potato', 'stable'], ['restaurant', 'visit', 'drink', 'addicting', 'elite'], ['broth', 'mussel', 'gave', 'wanted', 'heading'], ['spritz', 'aperol', 'confit', 'spaced', 'entrance'], ['heaven', 'taste', 'excitement', 'onto', 'accompaniment'], ['justify', 'daniel', 'charging', '3-', 'tony'], ['visit', 'wont', 'capture', 'first', 'cornbread'], ['tasha', 'prayerfully', 'magic', 'tge', 'meanwhile'], ['healed', 'leg', 'wake', '..took', 'prob'], ['grateful', 'crazy.lol', 'reopened', 'stir', 'covid/quarantine'], ['cornbread', 'go', '--', 'next', 'hesitation'], ['u', 'sweet', 'kind-', 'protest', 'amazing-'], ['queso', 'potato', 'salad', 'mac', 'portion'], ['briaunte', 'thank', 'review', 'kind', 'excitement'], ['jerk', 'chicken', 'small', 'corn', 'really'], ['panzerotti', 'bite', 'excitement', 'mix', 'onto'], ['panzerotti', 'classic', 'veer', 'beat', 'seriously'], ['past', 'weekly', 'stopping', 'hooked', 'salame'], ['panzerotti', 'pasquale', 'told', 'called', 'least'], ['panzerotti', 'cozy', 'bite', 'bumping', 'emotionally'], ['panzerotti', 'italian', 'you-', 'parent', 'puglia'], ['fried', 'panzerrotti', 'drove', 'salami', 'heavenly'], ['kid', 'panzerotti', 'part', 'calzone', 'artichoke'], ['walked', 'wow', 'great', 'must', 'place'], ['pocket', 'salame', 'spicy', 'carbs', 'breading'], ['sister', 'patio', 'panzerotti', 'classic', 'cute'], ['frenchy', 'truck', "'s", 'food', 'speel'], ['pear', 'universe', 'tart', 'david', 'guy'], ['godsend', 'parkway', 'heavenly', 'eastern', 'buttery'], ['mood', 'frenchy', 'pastry', 'salmon', 'park'], ['``', 'morning', 'happy', 'bonjour', 'routine'], ['frenchy', 'praying', 'diet', 'institution', 'pain'], ['frenchy', 'well', 'croissant', 'moon', 'truck'], ['all-', 'plain', 'truck', 'flaky', 'david'], ['parkway', 'designed', 'eastern', 'along', 'experience'], ['chocolate', 'croissant', 'nice', 'talk', 'delight'], ['parisian', 'baguette', 'closest', 'david', 'tip'], ['pizzeria', "l'industrie", 'excitement', 'grated', 'speel'], ['mozz', "l'industrie", 'ricotta', 'usually', 'order'], ['pizza', 'nirvana', 'nj', 'talking', 'sensible'], ['pizza', 'chaos', 'reheats', 'public', 'laughing'], ['pizza', "l'industrie", '--', 'exaggeration', 'titan'], ['pizza', 'slice', 'satisfied', 'crust', 'best'], ['pizza', 'burrata', 'pie', 'best', 'oily'], ['pizza', 'upper', 'giving', 'topping', 'balance'], ['bk', 'slice', 'pizza', 'meter', 'sauce'], ['wow', 'slice', 'pizza', 'lindustrie', 'tier'], ['pizza', 'selection', 'incredible', 'bit', 'gardner'], ['madame', 'poupon', 'excitement', 'freakin', 'onto'], ['buckwheat', 'friendliness', 'chez', 'tout', 'pour'], ['crepe', 'running', 'talked', 'sample', 'back'], ['crepe', 'owner', 'quality', 'appetizer', 'said'], ['authentic', 'galettes', 'breton', 'crêpes', 'discover'], ['passionate', 'crepe', 'really', 'native', 'cider'], ['crepe', 'brittany', 'asparagus', 'jam', 'sample'], ['crepe', 'extremely', 'ham', 'anything', 'butcher'], ['crêpe', 'transport', 'paris', 'provide', 'france'], ['crepe', 'super', 'caramel', 'hubster', 'coffee'], ['crepe', 'environment', 'buttery', 'thin', 'time'], ['palace', 'pita', 'sour', 'sprinkled', 'cured'], ['pudding', 'upon', 'space', '--', 'rice'], ['joke', 'quick-serve', 'match', 'dine-in', 'corner'], ['pickle', 'fan', 'pita', 'sandwich', 'threw'], ['order', 'mediterranean', 'anyone', 'call', 'either'], ['dollar', 'falafel', 'humus', 'couple', 'clean'], ['dont', 'im', 'wearing', 'ive', 'currently'], ['falafel', 'chicken', 'plate', 'kebab', 'rice'], ['hummus', 'lamb', 'love', "'ll", 'picky'], ['kufta', 'grabbed', 'kabob', 'falafel', 'husband'], ['garnish', 'quiet' ...
# The top_5 frequent words mentioned in each review in File 2 are:
# [['champion', 'coffee', 'surely', 'dare', 'strike'], ['frequent', 'card', 'add', 'visitor', 'employee'], ['lost', 'unwelcoming', 'woman', 'worst', 'working'], ['yes', 'yep', 'champ', 'patio', 'lit'], ['coffee', 'minimal', 'mix', 'get', 'shop'], ['spot', 'croissant', 'spending', 'various', 'includes'], ['couple', 'coffee', 'west', 'played', 'coast'], ['le', 'store', 'top', 'space', 'nice'], ['café', 'helpful', 'small-group', 'informal', 'conducting'], ['sandwich', 'coffee', 'lic', 'walk/drive', 'greenpoint'], ['baristas', 'cashier', 'rudely', '3x', 'smile'], ['ristorante', 'sorrentina', 'la', 'diner', 'yelp'], ['--', 'alla', 'main', 'course', 'dining'], ['scampi', 'shrimp', 'drenched', 'effectively', '24'], ['event', 'bridal', 'shower', 'beautiful', 'party'], ['really', 'listen', 'angry', 'crappy', 'terrible'], ['event', 'dining', 'beautiful', '3', 'awesome'], ['8clams', '12', 'order..', 'lady', 'excuse'], ['creme', 'baked', 'heavy', 'salmon', 'dry'], ['excellent', 'dinner', '2019.', 'july', 'pomodoro'], ['steak', 'closer', 'sauce', 'sorrentina', 'la'], ['bad', 'pasta', 'order', "n't", 'blew'], ['steakhouse', 'ember', 'time/earlier', 'disputed', 'dare'], ['seasoned', 'steak', 'home', 'amazing', 'well'], ['purchased', 'directly', 'shown', 'contact', 'coupon'], ['groupon', 'advise', 'clearly', 'sunday', 'give'], ['different', '``', 'tomato', "''", 'cod'], ['onion', 'ring', 'bayridge', 'accepted', 'major'], ['steak', 'calm', 'point', 'sauce', 'winking'], ['boyfriend', 'onion', 'good', 'hate', 'ribeye'], ['matter', 'updated', 'complaint', 'decor', 'groupon'], ['angel', 'speak', 'wanted', 'dark', 'outback'], ['steak', 'always', 'favorite', 'sauce', 'welcomed'], ['mythai', 'cafe', 'shitty', 'manger', 'dock'], ['social-distancing', 'thankfully', 'satays', 'takeout', 'curry'], ['2020', 'reminds', 'thailand', 'satay', 'sticky'], ['reminds', 'thailand', 'forget', 'sticky', 'satay'], ['crab', 'mau', 'bland', 'kee', 'dry'], ['thai', 'soup', '-pad', 'thom', 'yum'], ['satay', 'rice', 'fried', 'beef', 'skewer'], ['flavor', 'spice', 'almost', "n't", 'dab'], ['mango', 'thai', 'bit', 'spot', 'chic'], ['thai', 'pad', 'size', 'calamari', 'wing'], ['aesthetically', 'cute', 'flavorful', 'come', 'definitely'], ['dizzy', 'diner', "'s", 'disputed', 'dare'], ['flapjack', 'instead', 'hash', 'cheap', 'diner'], ['brunch', 'pretty', 'totally', 'patty', 'pickle'], ['pancake', '2', 'small', 'egg', 'race'], ['waited', 'asked', 'minute', 'use', 'took'], ['go', 'brunch', '4pm', 'thinking', 'pistachio'], ['love', 'e', 'heart', 'extraordinary', 'rccola'], ['renovated', 'good-excellent', 'year', 'always', 'neighborhood'], ["'s", 'review', 'workday', '7pm', 'finer/diner'], ['earlier', 'opened', 'ingredient', 'comfort', 'wish'], ['waffle', 'location', '2', 'jack', 'expected'], ['mori', 'time/earlier', 'disputed', 'dare', 'strike'], ['order', 'super', 'support', 'gosshhh', 'placed'], ['korean', 'effing', 'oyakusonburi', 'delighted', 'via'], ['presented', 'beautifully', 'managed', 'spectacular', 'affordable'], ['anniversary', 'buttery', 'preferred', 'delivered', 'husband'], ['didnt', 'bowl', 'park', 'uni', 'came'], ['already', 'upon', 'excited', 'uni', 'try'], ['sashimi', 'pork', 'inedible', 'maguro', 'curry'], ['uni', 'heh', 'scallop', 'twice', 'must'], ['people', 'ikura', 'uni', 'came', 'stale'], ['ikura', 'uni', "n't", 'great', 'couple'], ['public', 'douglas', 'house', 'beware', 'yelp'], ['liked', 'hand', 'time', 'u', 'really'], ['room', 'back', 'burger', 'party', 'well'], ['hh', 'burger', 'mr', 'littlefield', 'low-key'], ['pot', 'burger', 'pub', 'chicken', 'evening'], ['sandwich', 'soup', 'arrived', 'pub', 'grilled'], ['name', 'replayed', '90', '2000s', 'remix'], ['monday', 'happy', 'bar', "'m", 'seriousness'], ['monday', 'stephen', '...', 'either', 'know'], ['brewing', 'three', 'selection', 'bit', 'night'], ['one', "'s", 'drink', 'place', 'mary'], ['evil', 'olive', 'pizza', 'bar', 'time/earlier'], ['pizza', 'flavor', 'simply', 'mysta', 'shroom'], ['thankful', 'qua ...
# The top_5 frequent words mentioned in each review in File 3 are:
# [['anytime', 'broad', 'circulation', 'high-ceilined', 'become'], ['tapa', 'portion', 'went', 'small', 'group'], ['date', 'fun', 'sanitize', 'cautious', 'night'], ['delivery', 'dish', 'item', 'enough', 'fool-proof'], ['fried', 'batter', 'chicken', 'bulgogi', 'money'], ['knee', 'drunk', 'yelling', 'tend', 'healthy'], ['cotton', 'displayed', 'slide', 'dissolve', 'sky'], ["'think", 'k-town', 'turf', 'surf', 'soju'], ['ceviche', "'d", 'rapidly', 'massive/hectic', 'gaining'], ['karaoke', 'bulb', 'anytime', 'flavored', 'popcorn'], ['7', 'gizzard', 'shot', 'good', 'need'], ['spirit', 'hold', 'kitchen', 'fast', 'akin-'], ['esp', 'keeping', 'complying', 'capacity', 'shane'], ['shane', 'next', 'regular', 'customer', 'pub'], ['set', 'bookmarked', 'superrrr', 'hh', 'kiss'], ['bar', 'premise', 'cleverly', 'post-covid', 'tried'], ['management', 'marrow', 'burrata', 'particularly', 'hell'], ['oh', 'conversational', 'amazzzzzzzzziiinnnggg', 'everybody', 'christmas'], ['lengthy', 'luxurious', 'desperately', 'shove', 'purse'], ['loaded', 'fry', 'comparing', 'hangout', 'row'], ['hired', 'hustling', 'band', 'hangout', '11pm'], ['welcoming', 'business', 'chiara', "i'll", 'peep'], ['no.1', 'los', 'taco', 'akin-', 'barrier'], ['location', 'taco', 'native', 'socal', 'char-grilled'], ['taco', 'february', 'hotel', 'still', 'saw'], ['taco', 'nopales', 'table', 'quick', 'getting'], ['lettuce', 'sour', 'salsa', 'puzzle', 'mula'], ['lt1', 'cilantro', 'adobada', 'daughter', 'spent'], ['taco', 'los', 'carnitas', 'con', 'west'], ['def', 'cheap', 'manhattan', 'recommended', 'fast'], ['quesdilla', 'taco', "n't", 'scared', 'quesdillas'], ['--', 'cactus', 'adobada', 'asada', 'carne'], ['taco', '4.95', 'grab-n-go', '3.95', 'smokiness'], ['scott', 'tour', 'pizza', "'s", '2nd'], ['class', 'virtual', 'pizza', 'scott', 'making'], ['tour', 'pizza', 'sunday', 'bus', 'fun'], ['pizza', 'style', '3', 'different', 'excellent'], ['tour', 'pizza', 'exercise', 'great', 'load'], ['scott', 'energetic', 'great', 'spot', 'bus'], ['likes/loves', 'personality', 'tour-', 'engaged', 'importantly'], ['tour', 'scott', 'tomato', 'pizza', 'taught'], ['tour', 'pizza', 'scott', 'slice', 'extra'], ['pizza', 'cedric', 'history', 'informative', 'learn'], ['tour', 'guide', 'peter', 'pizza', 'going'], ['royal', 'halal', 'grill', 'food', 'akin-'], ['sauce', 'alam', 'mr.', 'cart', 'chicken'], ['over-indulged', 'algonquin', 'booze-wise', 'seattle', 'jimmy'], ['halal', 'cart', 'every-time', '10th', 'stamp'], ['hotel', 'tikka', 'masala', 'sauce', 'red'], ['cart', 'choice', 'people', 'punch', 'food'], ['halal', 'said-', 'royal', 'blown', 'ramen'], ['card', 'said', 'delicious..', 'nyc', 'annoying'], ['save', 'chicken', 'brings', 'halal', 'kati'], ['sometimes', 'corner', 'plate', 'redeeming', '44th'], ['tikka', 'choice', 'onion', 'variety', 'green'], ['café', 'bat', 'joey', 'mine', 'high-ceilined'], ['café', 'bakery', 'croissant', 'one', 'finally'], ['pastel', 'line', 'warr', 'jumanji', 'ther'], ['via', 'outdoor', 'half', 'pick', 'ordered'], ['tart', 'egg', 'portuguese', 'pack', '60'], ['extremely', 'baked', 'crispy', 'diameter', 'inch'], ['bica', 'pastry', 'tart', 'filling', 'egg'], ['attached', 'dance', 'til', 'joey', 'natas'], ['mind', 'absolutely', 'outer', 'custardy', 'patais'], ['ughhh', 'cinnamon', 'flakey', 'powdered', 'sooo'], ['oven', 'pastéis', 'natas', 'nata', 'de'], ['cafe', 'juice', 'green', 'akin-', 'barrier'], ['marcosantiago', 'encourage', 'it-', 'love', 'lox'], ['healer', 'companion', 'tropical', 'smoothy', 'smoothie'], ['smoothie', 'challenging', 'carlton', 'rewarding', 'community'], ['sandwich', 'filling', 'soup', 'v.', 'disliked'], ['vegan', 'recieved', 'yey', 'blessing', 'ashley'], ['smoothie', 'green', 'well-blended', 'bug', '20oz'], ['noticed', 'team', 'juice', 'see', 'rightly'], ['loved', 'underestimated', 'smoothy', 'timing', 'blend'], ['thank', 'blush', 'xty', 'shiniest', 'ability'], ['juice', 'cool', 'like', 'upset', 'blink'], ['no.1', 'los', 'taco', 'akin-', 'barrier'], ['smo ...
# The top_5 frequent words mentioned in each review in File 4 are:
# [['151', 'flight', 'patate', 'coated', 'hook'], ['killian', 'cali', 'provided', 'visited', 'thanks'], ['beer', 'since', 'kicker', 'erase', 'disgusting'], ['game', 'pitt', 'bar', 'finger', 'week'], ["'s", 'catch', 'super', 'clean', "n't"], ['bathroom', 'long', 'situation-', 'drink', 'food'], ['beer', '4pm', 'stating', 'breading', 'waffle'], ['5/10', 'margarita', 'okay', 'ambiance', 'margz'], ['beer', 'wine', 'reveals', 'poor', 'thirsty'], ['substance', 'strongbow', 'sunrise', 'ketchup', 'sticky/gooey'], ['wing', '10', "n't", 'ca', 'breeze'], ['sage', 'kitchen', 'tamika', 'con', 'hook'], ['love', 'donated', 'sinai', 'soo', 'pandemic'], ['paper', 'israeli', 'craft', 'wrapped', 'perfection'], ['sandwich', 'schnitzel', 'kosher', 'sage', 'office'], ['client', 'sandwich', 'horseradish', 'taking', 'also'], ['fresh', 'baguette', 'salami', 'israeli', 'egg'], ['favs', 'killer', 'ive', '7', 'everytime'], ['avoid', 'plastic', 'single', 'healthy', 'owner'], ['catering', 'issue', 'delivery', 'presentation', 'sandwich'], ['granola', 'assortment', 'homemade', 'vegan', 'fantastic'], ['everybody', 'changing', 'changer', 'fixed', 'provides'], ['vino', 'kest√©', 'pizza', 'tamika', 'speck'], ['gf', 'pizza', 'gluten', 'crust', 'free'], ['pizza', 'keste', 'gf', 'italian', 'remember'], ['wonderful', '10/10', 'endless', 'gluten', 'totally'], ['pie', "'s", 'ten-minute', 'margherita', 'essentially'], ['pizza', 'diavola', 'ever', 'person', 'way'], ['thank', 'tamika', 'patate', 'hook', 'promptly'], ['pizza', 'cheesecake', 'york', 'city', 'great'], ['pizza', 'love', '3-4', 'pistachio', 'outdoor'], ['italy', 'afterwards', 'finish', 'outdoor', 'great'], ['chewy', 'amazing', 'pizza', '10', 'place'], ['glaze', 'teriyaki', 'patate', 'coated', 'hook'], ['choice', 'took', 'competition', 'hace', 'random'], ['shumai', 'charred', 'takeout', 'rib', 'easy'], ['salmon', 'steak', 'quality', 'fishy', 'cover'], ['thigh', 'pork', 'dry', 'meat', 'piece'], ['get', 'correctly', 'seasoning', 'prepared', 'consistently'], ['sauce', 'definitely', 'ready', 'visit', 'especially'], ['breast', 'salad', 'rice', 'say', 'steak'], ['wiped', 'frequently', 'bright', 'trendy', 'interior'], ['chicken', 'steak', 'sweet', 'rice', 'rubbery'], ['rib', 'c.', 'cucumber', 'holy', 'get'], ['rye', 'house', 'frico', 'shaped', 'coated'], ['rye', 'whiskey', 'bf', 'house', "'m"], ['rye', 'house', 'flatiron', 'bar', 'never'], ['cocktail', 'looking', 'orchard', 'agave', 'crafted'], ['rye', 'skill', 'whip', 'knowledge', 'fashioned'], ['bar', 'cocktail', 'fashioned', 'weekend', 'well'], ['pretty', 'two', '4:19', '-the', 'glow'], ['popcorn', 'pepper', 'portion', 'comped', 'syrupy'], ['pickle', 'burger', 'quick', 'server', 'neither'], ['house', 'option', 'curd', 'mojito', 'devoured'], ['jack', 'ranch', 'dip', 'bomb', 'dressing'], ['trattoria', 'italienne', 'tamika', 'con', 'hook'], ['iteration', 'packed', 'whether', 'italienne', 'cuisine'], ['pasta', 'flavor', 'though', 'steak', 'menu'], ['10/10', 'app', 'sure', 'wifi', 'explained'], ['u', 'truffle', 'pasta', 'let', 'group'], ['even', 'thing', 'shortribs', 'paté', 'shame'], ['papardelle', 'fazoletti', 'trattoria', 'italienne', 'app'], ['goat', 'cheese', 'lunch', 'course', 'plus'], ['*i', 'pate', 'pappardelle', 'pickle', 'ragu'], ['heart', 'entree', 'butter', 'squash', 'ravioli'], ['sommelier', 'maitre', 'u', 'area', 'table'], ['ii', 'chop', 'shop', 'tamika', 'frico'], ['c', 'hooray', 'reopens', 'anxiously', 'awaiting'], ['chop', 'shop', 'work', 'depend', 'norwegian'], ['vegetarian', 'dumpling', 'veggie', 'restaurant', 'meat'], ['cauliflower', 'costly', 'asap', 'murray', '..'], ['noodle', 'chopshop', 'totally', 'day', 'chicken'], ['amount', 'bass', 'broccoli', 'visited', 'entree'], ['noodle', 'chicken', 'drunken', 'tough', 'fine'], ['service', 'pancetta', 'toddy', 'ginger-lemon', 'token'], ['asparagus', 'curry', 'microwaved', 'proceeded', 'send'], ['asparagus', 'curry', 'newt', 'proceeded', 'microwaved'], ['pit', 'hog', 'nyc', 'tamika', 'conversation'], ['taco', ...
